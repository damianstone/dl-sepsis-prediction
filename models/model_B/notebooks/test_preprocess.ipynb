# %%
import os
import sys
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from torch import nn

print(torch.__version__)

notebook_dir = os.getcwd()

project_root = os.path.abspath(os.path.join(notebook_dir, "../../.."))
print(project_root)
if project_root not in sys.path:
    sys.path.append(project_root)
# Out:
# 2.2.2
# /Users/damianstone/Documents/Code/machine-learning/dl-sepsis-prediction

# %%
from utils import get_data

DATA_PATH = get_data.get_dataset_abspath()
load_path = os.path.join(DATA_PATH, "Fully_imputed_dataset.parquet")
imputed_df = pd.read_parquet(load_path)

# %%
imputed_df.head(5)

# %%
"SOFA" in imputed_df

# %%
from models.model_B.pre_process_sofa import pre_process_sofa

pre_process_sofa("Fully_imputed_dataset.parquet","big_imputed_sofa.parquet")

# %%
from utils import get_data

DATA_PATH = get_data.get_dataset_abspath()
load_path = os.path.join(DATA_PATH, "big_imputed_sofa.parquet")
df = pd.read_parquet(load_path)

# %%
"SOFA" in df
# Out:
# True

# %%
df.head(5)
# Out:
#            HR      O2Sat       Temp         SBP        MAP        DBP  \
# 0  102.108491  91.419811  36.919203  128.165094  88.199717  67.007325
# 1   97.000000  95.000000  36.919203   98.000000  75.330000  67.007325
# 2   89.000000  99.000000  36.919203  122.000000  86.000000  67.007325
# 3   90.000000  95.000000  36.919203  122.000000  88.665000  67.007325
# 4  103.000000  88.500000  36.919203  122.000000  91.330000  67.007325
#
#         Resp    EtCO2  BaseExcess       HCO3  ...        WBC  Fibrinogen  \
# 0  24.712264  29.6875    0.091837  22.811236  ...  11.509132  360.909091
# 1  19.000000  29.6875    0.091837  22.811236  ...  11.509132  360.909091
# 2  22.000000  29.6875    0.091837  22.811236  ...  11.509132  360.909091
# 3  30.000000  29.6875   24.000000  22.811236  ...  11.509132  360.909091
# 4  24.500000  29.6875    0.091837  22.811236  ...  11.509132  360.909091
#
#     Platelets    Age  Gender  HospAdmTime  ICULOS  SepsisLabel  patient_id  \
# ...
